# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
DIR = "/home/aneeshashmi/xai/XAIM/data5/testing/PDG_0.03/Normal/Succ/Clean_x_attn"

# %%
attn = np.load(os.path.join(DIR, os.listdir(DIR)[20]), allow_pickle=True)
attn[0].shape
# Out:
# (224, 224)

# %%
import torch

# %%
s = torch.load('sample.pt')
s.shape
# Out:
# torch.Size([224, 224, 3])

# %%
# plt.imshow(attn[0], cmap='inferno')
plt.imshow(s.cpu())
